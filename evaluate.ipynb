# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/AI LAB PROJECT/evaluationnew.csv")

# %%
df
# Out:
#                                   Youtube Link  \
# 0  https://www.youtube.com/watch?v=6VZfeexme4c
# 1  https://www.youtube.com/watch?v=bFZHLYLzJ-Q
# 2  https://www.youtube.com/watch?v=3tKpbsHe1NQ
# 3  https://www.youtube.com/watch?v=XYDRuEQRTzE
# 4  https://www.youtube.com/watch?v=SRrgb8oxMxc
# 5  https://www.youtube.com/watch?v=Faj9EhkgBIY
# 6  https://www.youtube.com/watch?v=ULlGENlkMB8
# 7  https://www.youtube.com/watch?v=_pHglSTvgbI
# 8  https://www.youtube.com/watch?v=TfKSOIhLpNc
# 9  https://www.youtube.com/watch?v=2EimOYbvnnI
#
#                                          Video Title  \
# 0  North Korean leader Kim Jong Un enters Russia ...
# 1  US President Joe Biden's son Hunter indicted o...
# 2  Russia pilot tried to shoot down RAF aircraft ...
# 3  Libya floods leave more than 5,000 people dead...
# 4  US and Vietnam elevate diplomatic ties as Pres...
# 5  South China Sea tensions: Confrontation betwee...
# 6  UK accuses China of interfering in its democra...
# ...

# %%
references = df['Human summary'].tolist()
predictions_t5 =  df['T5 summary'].tolist()
predictions_spacy =  df['spaCy summary'].tolist()

# %%
# !pip install evaluate
# !pip install rouge-score
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 18.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24932 sha256=c049b55e9f716c58fc293d9f9e3638dd9357f0989ad2dfda105b7cb8a848e9a3
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# ...

# %%
import evaluate
rouge = evaluate.load('rouge')

# %%
results_t5 = rouge.compute(predictions=predictions_t5, references=references)
print(results_t5)
# Out:
# {'rouge1': 0.33927438640001784, 'rouge2': 0.09203496905278737, 'rougeL': 0.21890968300948083, 'rougeLsum': 0.21842526103969584}

# %%
results_spacy = rouge.compute(predictions=predictions_spacy, references=references)
print(results_spacy)
# Out:
# {'rouge1': 0.23183527903986972, 'rouge2': 0.046796506132552054, 'rougeL': 0.13656316713138045, 'rougeLsum': 0.13574972341646427}
